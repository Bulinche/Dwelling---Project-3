# %%
import pandas as pd
import requests
import json

# %%
schools = pd.read_csv('2019-hsRankings.csv')

# %%
schools.head()
# Out:
#    Rank                                             School    Type  Grades  \
# 0     1                 Academy For Information Technology  Public  12-Sep
# 1     2                    Union County Magnet High School  Public  12-Sep
# 2     3  Middlesex County Vocational Academy Math Scien...  Public  12-Sep
# 3     4                 Academy For Allied Health Sciences  Public  12-Sep
# 4     5                         Communications High School  Public  12-Sep
#
#                  Address           City   Zip  \
# 0      1776 Raritan Road  Scotch Plains  7076
# 1      1776 Raritan Road  Scotch Plains  7076
# 2   100 Technology Drive         Edison  8837
# 3      1776 Raritan Road  Scotch Plains  7076
# 4  1740 New Bedford Road           Wall  7719
#
#                                             District Is Charter Is Magnet  \
# 0  Union County Vocational-Technical School District         No     (n/a)
# 1  Union County Vocational-Technical School District         No     (n/a)
# 2  Middlesex County Vocational and Technical Scho...         No     (n/a)
# 3  Union County Vocational-Technical School District         No     (n/a)
# 4         Monmouth County Vocational School District         No     (n/a)
#
#   Is Virtual Is Title I           Phone  \
# 0         No         No  (908) 889-8288
# 1         No         No  (908) 889-8288
# 2         No         No  (732) 452-2600
# 3         No        Yes  (908) 889-8288
# 4         No         No  (732) 681-1010
#
#                                  Full_Address
# 0  1776 Raritan Road, Scotch Plains, NJ 07076
# 1  1776 Raritan Road, Scotch Plains, NJ 07076
# 2      100 Technology Drive, Edison, NJ 08837
# 3  1776 Raritan Road, Scotch Plains, NJ 07076
# 4       1740 New Bedford Road, Wall, NJ 07719

# %%
full_address = []
for index,row in schools.iterrows():
    full_address.append(f"{row['Address']}, {row['City']}, NJ 0{row['Zip']}")

# %%
schools['Full_Address']=full_address

# %%
GoogleAPI='AIzaSyCJCoD8hXTCvE4Wswuu-Kvra5FjeRFJSxY'

# %%
latlonToSchool = f"https://maps.googleapis.com/maps/api/geocode/json?sensor=true&key={GoogleAPI}&address="
lats = []
lons = []

for index,row in schools.iterrows():
    query = f"{latlonToSchool}{row['Full_Address']}"
    result = requests.get(query).json()
    lats.append(result['results'][0]['geometry']['location']['lat'])
    lons.append(result['results'][0]['geometry']['location']['lng'])
#     print(query)

# %%
test = 'https://maps.googleapis.com/maps/api/geocode/json?sensor=true&key=AIzaSyCJCoD8hXTCvE4Wswuu-Kvra5FjeRFJSxY&address=1776%20Raritan%20Road,%20Scotch%20Plains,%20NJ%2007076'
result = requests.get(test).json()

# %%
result['results'][0]['geometry']['location']['lng']
# Out:
# -74.3570355

# %%
schools['Latitude'] = lats
schools['Longitude'] = lons

# %%
schools.to_csv('2019-hsRankingsLatLng.csv')

# %%
df = pd.read_csv('2019-hsRankingsLatLng.csv')
df
# Out:
#      Unnamed: 0  Rank                                             School  \
# 0             0     1                 Academy For Information Technology
# 1             1     2                    Union County Magnet High School
# 2             2     3  Middlesex County Vocational Academy Math Scien...
# 3             3     4                 Academy For Allied Health Sciences
# 4             4     5                         Communications High School
# ..          ...   ...                                                ...
# 409         409   410                                 Camden High School
# 410         410   411     School of Government and Public Administration
# 411         411   412              Eagle Academy for Young Men of Newark
# 412         412   413          Burlington County Alternative High School
# 413         413   414                    Marion P. Thomas Charter School
#
#                              Type     Grades                Address  \
# 0                          Public     12-Sep      1776 Raritan Road
# 1                          Public     12-Sep      1776 Raritan Road
# 2                          Public     12-Sep   100 Technology Drive
# 3                          Public     12-Sep      1776 Raritan Road
# 4                          Public     12-Sep  1740 New Bedford Road
# ..                            ...        ...                    ...
# 409                        Public     12-Sep    1875 Park Boulevard
# 410                        Public     12-Sep        150 Park Avenue
# 411                        Public     12-May  279 Chancellor Avenue
# 412                        Public     12-Jun       1020 Briggs Road
# 413  Public, Charter, Alternative  PK, KG-12  88-108 Shipman Street
#
#               City   Zip                                           District  \
# 0    Scotch Plains  7076  Union County Vocational-Technical School District
# 1    Scotch Plains  7076  Union County Vocational-Technical School District
# 2           Edison  8837  Middlesex County Vocational and Technical Scho...
# 3    Scotch Plains  7076  Union County Vocational-Technical School District
# 4             Wall  7719         Monmouth County Vocational School District
# ..             ...   ...                                                ...
# 409         Camden  8103                        Camden City School District
# 410       Paterson  7501                    Paterson Public School District
# 411         Newark  7112                      Newark Public School District
# 412   Mount Laurel  8054  Burlington County Special Services School Dist...
# 413         Newark  7102                    Marion P. Thomas Charter School
#
#     Is Charter Is Magnet Is Virtual Is Title I           Phone  \
# 0           No     (n/a)         No         No  (908) 889-8288
# 1           No     (n/a)         No         No  (908) 889-8288
# 2           No     (n/a)         No         No  (732) 452-2600
# 3           No     (n/a)         No        Yes  (908) 889-8288
# 4           No     (n/a)         No         No  (732) 681-1010
# ..         ...       ...        ...        ...             ...
# 409         No     (n/a)         No        Yes  (856) 966-5100
# 410         No     (n/a)         No        Yes  (973) 321-2488
# 411         No     (n/a)         No        Yes  (973) 733-1234
# 412         No     (n/a)         No         No  (609) 894-9311
# 413        Yes     (n/a)         No        Yes  (973) 621-0060
#
#                                    Full_Address   Latitude  Longitude
# 0    1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 1    1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 2        100 Technology Drive, Edison, NJ 08837  40.504556 -74.369550
# 3    1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 4         1740 New Bedford Road, Wall, NJ 07719  40.169901 -74.062049
# ..                                          ...        ...        ...
# 409       1875 Park Boulevard, Camden, NJ 08103  39.930925 -75.095334
# 410         150 Park Avenue, Paterson, NJ 07501  40.914305 -74.159870
# 411     279 Chancellor Avenue, Newark, NJ 07112  40.709304 -74.220042
# 412    1020 Briggs Road, Mount Laurel, NJ 08054  39.971897 -74.899045
# 413     88-108 Shipman Street, Newark, NJ 07102  40.732852 -74.179822
#
# [414 rows x 17 columns]

# %%
df.set_index('Rank', inplace=True)

# %%
df.drop(columns={'Type', 'Grades', 'Is Charter', 'Is Magnet', 'Is Virtual', 'Is Title I', 'Unnamed: 0', 'Phone'}, inplace=True)

# %%
df
# Out:
#                                                  School  \
# Rank
# 1                    Academy For Information Technology
# 2                       Union County Magnet High School
# 3     Middlesex County Vocational Academy Math Scien...
# 4                    Academy For Allied Health Sciences
# 5                            Communications High School
# ...                                                 ...
# 410                                  Camden High School
# 411      School of Government and Public Administration
# 412               Eagle Academy for Young Men of Newark
# 413           Burlington County Alternative High School
# 414                     Marion P. Thomas Charter School
#
#                     Address           City   Zip  \
# Rank
# 1         1776 Raritan Road  Scotch Plains  7076
# 2         1776 Raritan Road  Scotch Plains  7076
# 3      100 Technology Drive         Edison  8837
# 4         1776 Raritan Road  Scotch Plains  7076
# 5     1740 New Bedford Road           Wall  7719
# ...                     ...            ...   ...
# 410     1875 Park Boulevard         Camden  8103
# 411         150 Park Avenue       Paterson  7501
# 412   279 Chancellor Avenue         Newark  7112
# 413        1020 Briggs Road   Mount Laurel  8054
# 414   88-108 Shipman Street         Newark  7102
#
#                                                District  \
# Rank
# 1     Union County Vocational-Technical School District
# 2     Union County Vocational-Technical School District
# 3     Middlesex County Vocational and Technical Scho...
# 4     Union County Vocational-Technical School District
# 5            Monmouth County Vocational School District
# ...                                                 ...
# 410                         Camden City School District
# 411                     Paterson Public School District
# 412                       Newark Public School District
# 413   Burlington County Special Services School Dist...
# 414                     Marion P. Thomas Charter School
#
#                                     Full_Address   Latitude  Longitude  \
# Rank
# 1     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 2     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 3         100 Technology Drive, Edison, NJ 08837  40.504556 -74.369550
# 4     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 5          1740 New Bedford Road, Wall, NJ 07719  40.169901 -74.062049
# ...                                          ...        ...        ...
# 410        1875 Park Boulevard, Camden, NJ 08103  39.930925 -75.095334
# 411          150 Park Avenue, Paterson, NJ 07501  40.914305 -74.159870
# 412      279 Chancellor Avenue, Newark, NJ 07112  40.709304 -74.220042
# 413     1020 Briggs Road, Mount Laurel, NJ 08054  39.971897 -74.899045
# 414      88-108 Shipman Street, Newark, NJ 07102  40.732852 -74.179822
#
#       EduScore
# Rank
# 1          500
# 2          499
# 3          498
# 4          496
# 5          495
# ...        ...
# 410          6
# 411          5
# 412          4
# 413          2
# 414          1
#
# [414 rows x 9 columns]

# %%
eduScore = []
records = len(df)
for index,r in df.iterrows():
    eduScore.append(round(500*(records+1-index)/records))
df['EduScore'] = eduScore

# %%
df.to_csv("eduSlider.csv")

# %%
df
# Out:
#                                                  School  \
# Rank
# 1                    Academy For Information Technology
# 2                       Union County Magnet High School
# 3     Middlesex County Vocational Academy Math Scien...
# 4                    Academy For Allied Health Sciences
# 5                            Communications High School
# ...                                                 ...
# 410                                  Camden High School
# 411      School of Government and Public Administration
# 412               Eagle Academy for Young Men of Newark
# 413           Burlington County Alternative High School
# 414                     Marion P. Thomas Charter School
#
#                     Address           City   Zip  \
# Rank
# 1         1776 Raritan Road  Scotch Plains  7076
# 2         1776 Raritan Road  Scotch Plains  7076
# 3      100 Technology Drive         Edison  8837
# 4         1776 Raritan Road  Scotch Plains  7076
# 5     1740 New Bedford Road           Wall  7719
# ...                     ...            ...   ...
# 410     1875 Park Boulevard         Camden  8103
# 411         150 Park Avenue       Paterson  7501
# 412   279 Chancellor Avenue         Newark  7112
# 413        1020 Briggs Road   Mount Laurel  8054
# 414   88-108 Shipman Street         Newark  7102
#
#                                                District  \
# Rank
# 1     Union County Vocational-Technical School District
# 2     Union County Vocational-Technical School District
# 3     Middlesex County Vocational and Technical Scho...
# 4     Union County Vocational-Technical School District
# 5            Monmouth County Vocational School District
# ...                                                 ...
# 410                         Camden City School District
# 411                     Paterson Public School District
# 412                       Newark Public School District
# 413   Burlington County Special Services School Dist...
# 414                     Marion P. Thomas Charter School
#
#                                     Full_Address   Latitude  Longitude  \
# Rank
# 1     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 2     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 3         100 Technology Drive, Edison, NJ 08837  40.504556 -74.369550
# 4     1776 Raritan Road, Scotch Plains, NJ 07076  40.618051 -74.357035
# 5          1740 New Bedford Road, Wall, NJ 07719  40.169901 -74.062049
# ...                                          ...        ...        ...
# 410        1875 Park Boulevard, Camden, NJ 08103  39.930925 -75.095334
# 411          150 Park Avenue, Paterson, NJ 07501  40.914305 -74.159870
# 412      279 Chancellor Avenue, Newark, NJ 07112  40.709304 -74.220042
# 413     1020 Briggs Road, Mount Laurel, NJ 08054  39.971897 -74.899045
# 414      88-108 Shipman Street, Newark, NJ 07102  40.732852 -74.179822
#
#       EduScore
# Rank
# 1          500
# 2          499
# 3          498
# 4          496
# 5          495
# ...        ...
# 410          6
# 411          5
# 412          4
# 413          2
# 414          1
#
# [414 rows x 9 columns]
