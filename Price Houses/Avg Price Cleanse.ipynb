# %%
import requests
import pandas as pd
import json
import pymongo
import json
import math

# %%
conn2 = 'mongodb://localhost:27017'
# Pass connection to the pymongo instance.
client2 = pymongo.MongoClient(conn2)

# Connect to a database. Will create one if not already available.
db2 = client2.Dwelling_db
cities = db2.city_lat_lon.find()
gC = []

for x in cities:
    gC.append(x['City'])

gC = sorted(gC)

# %%
sp2000 = pd.read_csv("AvgSalesPrice2000.csv")

# %%
spC = sp2000['City'].to_list()
spC = sorted(spC)
spC
#
# Out:
# ['ABERDEEN TWP',
#  'ABSECON CITY',
#  'ALEXANDRIA TWP',
#  'ALLAMUCHY TWP',
#  'ALLENDALE BORO',
#  'ALLENHURST BORO',
#  'ALLENTOWN BORO',
#  'ALLOWAY TWP',
#  'ALPHA BORO',
#  'ALPINE BORO',
#  'ANDOVER BORO',
#  'ANDOVER TWP',
#  'ASBURY PARK CITY',
#  'ATLANTIC CITY CITY',
#  'ATLANTIC HIGHLANDS BORO',
#  'AUDUBON BORO',
#  'AUDUBON PARK BORO',
#  'AVALON BORO',
#  'AVON-BY-THE-SEA BOR',
#  'BARNEGAT LIGHT BORO',
#  'BARNEGAT TWP',
#  'BARRINGTON BORO',
#  'BASS RIVER TWP',
#  'BAY HEAD BORO',
#  'BAYONNE CITY',
#  'BEACH HAVEN BORO',
#  'BEACHWOOD BORO',
#  'BEDMINSTER TWP',
#  'BELLEVILLE TWP',
#  'BELLMAWR BORO',
#  'BELMAR BORO',
#  'BELVIDERE TOWN',
#  'BERGENFIELD BORO',
#  'BERKELEY BORO',
#  'BERKELEY HEIGHTS TWP',
#  'BERLIN BORO',
#  'BERLIN TWP',
#  'BERNARDS TWP',
#  'BERNARDSVILE BORO',
#  'BETHLEHAM TWP',
#  'BEVERLY CITY',
#  'BLAIRSTOWN TWP',
#  'BLOOMFIELD TWP',
#  'BLOOMINGDALE BORO',
#  'BLOOMSBURY BORO',
#  'BOGOTA BORO',
#  'BOONTON TOWN',
#  'BOONTON TWP',
# ...

# %%
# count = 0
# for g in gC:
#     print(f"{count}: {g}")
#     count += 1
# goldenC
# Out:
# 0: Absecon
# 1: Adelphia
# 2: Allamuchy
# 3: Allendale
# 4: Allenhurst
# 5: Allentown
# 6: Allenwood
# 7: Alloway
# 8: Alpine
# 9: Andover
# 10: Annandale
# 11: Asbury
# 12: Asbury Park
# 13: Atco
# 14: Atlantic City
# 15: Atlantic Highlands
# 16: Audubon
# 17: Augusta
# 18: Avalon
# 19: Avenel
# 20: Avon By The Sea
# 21: Baptistown
# 22: Barnegat
# 23: Barnegat Light
# 24: Barrington
# 25: Basking Ridge
# 26: Bayonne
# 27: Bayville
# 28: Beach Haven
# 29: Beachwood
# 30: Bedminster
# 31: Belford
# 32: Belle Mead
# 33: Belleville
# 34: Bellmawr
# 35: Belmar
# 36: Belvidere
# 37: Bergenfield
# 38: Berkeley Heights
# 39: Berlin
# 40: Bernardsville
# 41: Beverly
# 42: Birmingham
# 43: Blackwood
# 44: Blairstown
# 45: Blawenburg
# 46: Bloomfield
# 47: Bloomingdale
# 48: Bloomsbury
# 49: Bogota
# 50: Boonton
# 51: Bordentown
# 52: Bound Brook
# 53: Bradley Beach
# 54: Branchville
# 55: Brick
# 56: Bridgeport
# 57: Bridgeton
# 58: Bridgewater
# 59: Brielle
# 60: Brigantine
# 61: Broadway
# ...

# %%
rm = 'RemoveMe'

conv={
    'ABERDEEN TWP' : rm,
    'ABSECON CITY' : gC[0],
    'ALEXANDRIA TWP' : rm,
    'ALLAMUCHY TWP' : gC[2],
    'ALLENDALE BORO': gC[3],
    'ALLENHURST BORO' : gC[4],
    'ALLENTOWN BORO' : gC[5],
    'ALLOWAY TWP' : gC[7],
    'ALPHA BORO' : rm,
    'ALPINE BORO' : gC[8],
    'ANDOVER BORO': gC[9],
    'ANDOVER TWP' : gC[9], #combine
    'ASBURY PARK CITY': gC[12],
    'ATLANTIC CITY CITY' : gC[14],
    'ATLANTIC HIGHLANDS BORO': gC[15],
    'AUDUBON BORO' : gC[16],
    'AUDUBON PARK BORO' : rm,
    'AVALON BORO' : gC[17],
    'AVON-BY-THE-SEA BOR' : gC[20],
    'BARNEGAT LIGHT BORO' : gC[23],
    'BARNEGAT TWP' : gC[22],
    'BARRINGTON BORO' : gC[24],
    'BASS RIVER TWP' : rm,
    'BAY HEAD BORO' : rm,
    'BAYONNE CITY' : gC[26],
    'BEACH HAVEN BORO' : gC[28],
    'BEACHWOOD BORO' : gC[29],
    'BEDMINSTER TWP' : gC[30],
    'BELLEVILLE TWP' : gC[33],
    'BELLMAWR BORO' : gC[34],
    'BELMAR BORO' : gC[35],
    'BELVIDERE TOWN' : gC[36],
    'BERGENFIELD BORO' : gC[37],
    'BERKELEY BORO' : rm,
    'BERKELEY HEIGHTS TWP' : gC[38],
    'BERLIN BORO' : gC[39],
    'BERLIN TWP' : gC[39], # combine
    'BERNARDS TWP' : rm,
    'BERNARDSVILE BORO' : gC[40],
    'BETHLEHAM TWP' : rm,
    'BEVERLY CITY' : gC[41],
    'BLAIRSTOWN TWP' : gC[44],
    'BLOOMFIELD TWP' : gC[46],
    'BLOOMINGDALE BORO' : gC[47],
    'BLOOMSBURY BORO' : gC[48],
    'BOGOTA BORO' : gC[49],
    'BOONTON TOWN' : gC[50],
    'BOONTON TWP' : gC[50], #combine
    'BORDENTOWN CITY' : gC[51], #c
    'BORDENTOWN TWP'  gC[51],#c
    'BOUND BROOK BORO' : gC[52],
    'BRADLEY BEACH BORO' : gC[53],
    'BRANCHBURG TWP' : rm,
    'BRANCHVILLE BORO' : gC[54],
    'BRICK TWP' : gC[55],
    'BRIDGETON CITY' : gC[57],
    'BRIDGEWATER TWP' : gC[58],
    'BRIELLE BORO' : gC[59],
    'BRIGANTINE CITY' : gC[60],
    'BROOKLAWN BORO' : rm,
    'BUENA BORO' : gC[65],
    'BUENA VISTA TWP' : rm,
    'BULTER BORO' : gC[67],
    'BURLINGTON CITY' : gC[66],
    'BURLINGTON TWP' : gC[66],  #com
    'BYRAM TWP' : rm,
    'CALDWELL TWP' : gC[69],
    'CALIFON BORO' : gC[70],
    'CAMDEN CITY' : gC[71],
    'CAPE MAY CITY' : gC[72],
    'CAPE MAY POINT BORO' : gC[74],
    'CARLSTADT BORO' : gC[75],
    'CARNEYS POINT TWP' : rm,
    'CARTERET BORO' : gC[76],
    'CEDAR GROOVE TWP' : gC[78],
    'CHATHAM BORO' : gC[82],
    'CHATHAM TWP' : gC[82], # comb
    'CHERRY HILL TWP' : gC[84],
    'CHESILHURST BORO' : rm,
    'CHESTER BORO' : gC[85],
    'CHESTER TWP' : gC[85], #comb
    'CHESTERFIELD TWP' : gC[86],
    'CINNAMINSON TWP' : rm,
    'CLARK TWP' : gC[87],
    'CLAYTON BORO' : gC[89],
    'CLEMENTON BORO' : gC[90],
    'CLIFFSIDE PARK BORO' : gC[91],
    'CLIFTON CITY' : gC[93],
    'CLINTON TOWN' : gC[94],
    'CLINTON TWP' : gC[94], #combine
    'CLOSTER BORO' : gC[95],
    'COLLINGSWOOD BORO' : gC[96],
    'COLTS NECK TWP' : gC[99],
    'COMMERCIAL TWP' : rm,
    'CORBIN CITY CITY' : rm,
    'CRANBURY TWP' : gC[103],
    'CRANFORD TWP' : gC[104],
    'CRESSKILL BORO' : gC[106],
    'DEAL BORO' : gC[108],
    'DEERFIELD TWP' : gC[110],
    'DELANCO TWP' : rm,
    'DELAWARE TWP' : gC[111],
    'DELRAN TWP' : rm,
    'DEMAREST BORO' : gC[113],
    'DENNIS TWP' : gC[114],
    'DENVILLE TWP' : gC[115],
    'DEPTFORD TWP' : gC[116],
    'DOVER TOWN' gC[120],
    'DOWNE TWP' : rm,
    'DUMONT BORO' : gC[121],
    'DUNELLEN BORO' : gC[122],
    'EAGLESWOOD TWP' : rm,
    'EAST AMWELL TWP' : rm,
    'EAST BRUNSWICK TWP' : gC[123],
    'EAST GREENWICH TWP' : rm,
    'EAST HANOVER TWP' : gC[124],
    'EAST NEWARK BORO' : rm,
    'EAST ORANGE CITY' : gC[125],
    'EAST RUTHERFORD BORO' : gC[126],
    'EAST WINDSOR TWP' : rm,
    'EASTAMPTON TWP' : rm,
    'EATONTOWN BORO' : gC[127],
    'EDGEWATER BORO' : gC[128],
    'EDGEWATER PARK TWP' : rm,
    'EDISON TWP' : gC[129],
    'EGG HARBOR CITY' : gC[130],
    'EGG HARBOR TWP' : gC[131],
    'ELIZABETH CITY': gC[132],
    'ELK TWP' : rm,
    'ELMER BORO' : gC[133],
    'ELMWOOD BORO' : gC[135],
    'ELSINBORO TWP' : rm,
    'EMERSON BORO' : gC[136],
    'ENGLEWOOD CITY' : gC[137],
    'ENGLEWOOD CLIFFS BORO' : gC[138],
    'ENGLISHTOWN BORO' : gC[139],
    'ESSEX FELLS TWP' : gC[140],
    'ESTELL MANOR CITY' : gC[141],
    'EVESHAM TWP' : rm,
    'EWING TWP': rm,
    'FAIR HAVEN BORO' : gC[143],
    'FAIRFIELD TWP' : gC[145],
    'FAIRFIELD TWP' : gC[145], #combine
    'FAIRLAWN BORO' : gC[144],
    'FAIRVIEW BORO' : gC[147],
    'FANWOOD BORO' : gC[148],
    'FAR HILLS BORO' : gC[149],
    'FARMINGDALE BORO' : gC[150],
    'FIELDSBORO BORO' : rm,
    'FLEMINGTON BORO' : gC[153],
    'FLORENCE TWP' : gC[154],
    'FLORHAM PARK BORO' : gC[155],
    'FOLSOM BORO' : rm,
    'FORT LEE BORO' : gC[159],
    'FRANKFORD TWP' : rm,
    'FRANKLIN BORO' : gC[162],
    'FRANKLIN LAKES BORO' : gC[163],
    'FRANKLIN TWP' : gC[162],
    'FRANKLIN TWP' : gC[162], #combine
    'FRANKLIN TWP' : gC[162], # combine
    'FRANKLIN TWP' : gC[162], # combine
    'FREDON TWP' : rm,
    'FREEHOLD BORO' : gC[166],
    'FREEHOLD TWP' : gC[166],
    'FRELINGHUYSEN TWP' : rm,
    'FRENCHTOWN BORO' : gC[167],
    'GALLOWAY TWP' : rm,
    'GARFIELD CITY' : gC[168],
    'GARWOOD BORO' : gC[169],
    'GIBBSBORO BORO' : gC[170],
    'GLASSBORO BORO' : gC[174],
    'GLEN GARDNER BORO' : gC[176],
    'GLEN RIDGE TWP' : gC[177],
    'GLEN ROCK BORO' : gC[178],
    'GLOUCESTER CITY' : gC[181],
    'GLOUCESTER TWP' : gC[181], #combine
    'GREEN BROOK TWP' : rm,
    'GREEN TWP' : gC[185],
    'GREENWICH TWP' : gC[187],
    'GREENWICH TWP' : gC[187], # combine
    'GREENWICH TWP' : gC[187], # combine
    'GUTTENBERG TOWN' : rm,
    'HACKENSACK CITY' : gC[190],
    'HACKETTSTOWN TOWN' : gC[191],
    'HADDON HEIGHTS BORO' : gC[192],
    'HADDON TWP' : gC[193],
    'HADDONFIELD BORO' : gC[194],
    'HAINESPORT TWP' : gC[195],
    'HALEDON BORO' : gC[196],
    'HAMBURG BORO' : gC[197],
    'HAMILTON TWP' : rm,
    'HAMILTON TWP' : rm,
    'HAMMONTON TOWN' : gC[198],
    'HAMPTON BORO' : gC[199],
    'HAMPTON BORO' : gC[199],
    'HANOVER TWP' : rm,
    'HARDING TWP' : rm,
    'HARDWICK TWP' : rm,
    'HARDYSTON BORO' : rm,
    'HARMAONY TWP' : rm,
    'HARRINGTON PARK BORO' : gC[201],
    'HARRISON TOWN' : gC[202],
    'HARRISON TWP' : gC[202], #c
    'HARVEY CEDARS BORO' : rm,
    'HASBROUCK HEIGHTS BORO' : gC[204],
    'HAWORTH BORO' : gC[206],
    'HAWTHORNE BORO' : gC[207],
    'HAZLET TWP' : gC[208],
    'HELMETTA BORO' : gC[210],
    'HI-NELLA BORO' : rm,
    'HIGH BRIDGE BORO' : gC[213],
    'HIGHLAND PARK BORO' : gC[215],
    'HIGHLANDS BORO' : gC[216],
    'HIGHTSTOWN BORO' : gC[217],
    'HILLSBOROUGH TWP' : gC[218],
    'HILLSDALE BORO' : gC[219],
    'HILLSIDE TWP' : gC[220],
    'HO-HO-KUS BORO' : gC[221],
    'HOBOKEN CITY' : gC[222],
    'HOLLAND TWP' : rm,
    'HOLMDEL TWP' : gC[223],
    'HOPATCONG BORO' : gC[224],
    'HOPE TWP' : gC[225],
    'HOPEWELL BORO' : gC[226],
    'HOPEWELL TWP' : gC[226], # com
    'HOPEWELL TWP' : gC[226], # com
    'HOWELL TWP' : gC[227],
    'INDEPENDENCE TWP' : rm,
    'INTERLAKEN BORO' : rm,
    'IRVINGTON TWP' : gC[230],
    'ISLAND HEIGHTS BORO' : gC[232],
    'JACKSON TWP' : gC[233],
    'JAMESBURG BORO' : rm,
    'JEFFERSON TWP' : rm,
    'JERSEY CITY CITY' : gC[234],
    'KEANSBURG BORO' : gC[238],
    'KEARNY TOWN' : gC[239],
    'KENILWORTH BORO' : gC[242],
    'KEYPORT BORO' : gC[244],
    'KINGWOOD TWP',
    'KINNELON BORO',
    'KNOWLTON TWP',
#     'LACEY TWP',
#     'LAFAYETTE BORO',
#     'LAKE COMO BORO',
#     'LAKEHURST BORO',
#     'LAKEWOOD TWP',
#     'LAMBERTVILLE CITY ',
#     'LAUREL SPRINGS BORO',
#     'LAVALLETTE BORO',
#     'LAWNSIDE BORO',
#     'LAWRENCE TWP',
#     'LAWRENCE TWP',
#     'LEBANON BORO',
#     'LEBANON TWP',
#     'LEONIA BORO',
#     'LIBERTY TWP',
#     'LINCOLN PARK BORO',
#     'LINDEN CITY',
#     'LINDENWOLD BORO',
#     'LINWOOD CITY',
#     'LITTLE EGG HARBOR TWP',
#     'LITTLE FALLS TWP',
#     'LITTLE FERRY BORO',
#     'LITTLE SILVER BORO',
#     'LIVINGSTON TWP',
#     'LOCH ARBOUR VILLAGE',
#     'LODI BORO',
#     'LOGAN TWP',
#     'LONG BEACH TWP',
#     'LONG BRANCH CITY',
#     'LONG HILL TWP',
#     'LONGPORT BORO',
#     'LOPATCONG TWP',
#     'LOWER ALLOWAYS CREEK TWP',
#     'LOWER TWP',
#     'LUMBERTON TWP',
#     'LYNDHURST TWP',
#     'MADISON BORO',
#     'MAGNOLIA BORO',
#     'MAHWAH TWP',
#     'MANALAPAN TWP',
#     'MANASQUAN BORO',
#     'MANCHESTER TWP',
#     'MANNINGTON TWP',
#     'MANSFIELD TWP',
#     'MANSFIELD TWP',
#     'MANTOLOKING BORO',
#     'MANUTA TWP',
#     'MANVILLE BORO',
#     'MAPLE SHADE TWP',
#     'MAPLEWOOD TWP',
#     'MARGATE CITY CITY',
#     'MARLBORO TWP',
#     'MATAWAN BORO',
#     'MAURICE RIVER TWP',
#     'MAYWOOD BORO',
#     'MEDFORD LAKES BORO',
#     'MEDFORD TWP',
#     'MENDHAM BORO',
#     'MENDHAM TWP',
#     'MERCHANTVILLE BORO',
#     'METUCHEN BORO',
#     'MIDDLE TWP',
#     'MIDDLESEX BORO',
#     'MIDDLETOWN TWP',
#     'MIDLAND PARK BORO',
#     'MILFORD BORO',
#     'MILLBURN TWP',
#     'MILLSTONE BORO',
#     'MILLSTONE TWP',
#     'MILLTOWN BORO',
#     'MILLVILLE CITY',
#     'MINE HILL TWP',
#     'MONMOUTH BEACH BORO',
#     'MONROE TWP',
#     'MONROE TWP',
#     'MONTAGUE TWP',
#     'MONTCLAIR TWP',
#     'MONTGOMERY TWP',
#     'MONTVALE BORO',
#     'MONTVILLE TWP',
#     'MOONACHIE BORO',
#     'MOORESTOWN TWP',
#     'MORRIS PLAINS BORO',
#     'MORRIS TWP',
#     'MORRISTOWN TOWN',
#     'MOUNT ARLINGTON BORO',
#     'MOUNT EPHRAIN BORO ',
#     'MOUNT HOLLY TWP',
#     'MOUNT LAUREL TWP',
#     'MOUNT OLIVE TWP',
#     'MOUNTAIN LAKES BORO',
#     'MOUNTAINSIDE BORO',
#     'MULLICA TWP',
#     'NATIONAL PARK BORO',
#     'NEPTUNE CITY BORO',
#     'NEPTUNE TWP',
#     'NETCONG BORO',
#     'NEW BRUNSWICK CITY',
#     'NEW HANOVER TWP',
#     'NEW MILFORD BORO',
#     'NEW PROVIDENCE BORO',
#     'NEWARK CITY',
#     'NEWFIELD BORO',
#     'NEWTON TOWN',
#     'NORTH ARLINGTON BORO',
#     'NORTH BERGEN TWP',
#     'NORTH BRUNSWICK TWP',
#     'NORTH CALDWELL TWP',
#     'NORTH HALEDON BORO',
#     'NORTH HANOVER TWP',
#     'NORTH PLAINFIELD BORO',
#     'NORTH WILDWOOD CITY',
#     'NORTHFIELD CITY',
#     'NORTHVALE BORO',
#     'NORWOOD BORO',
#     'NUTLEY TWP',
#     'OAKLAND BORO',
#     'OAKLYN BORO',
#     'OCEAN CITY CITY',
#     'OCEAN GATE BORO',
#     'OCEAN TWP',
#     'OCEAN TWP',
#     'OCEANPORT BORO',
#     'OGDENSBURG BORO',
#     'OLD BRIDGE TWP',
#     'OLD TAPPAN BORO',
#     'OLDSMAN TWP',
#     'ORADELL BORO',
#     'ORANGE CITY TWP',
#     'OXFORD TWP',
#     'PALISADES PARK BORO',
#     'PALMYRA BORO',
#     'PARAMUS BORO',
#     'PARK RIDGE BORO',
#     'PARSIPPANY-TROY HILLS TWP',
#     'PASSAIC CITY',
#     'PATERSON CITY',
#     'PAULSBORO BORO',
#     'PEAPACK-GLADSTONE BORO',
#     'PEMBERTON BORO',
#     'PEMBERTON TWP',
#     'PENNIGTON BORO',
#     'PENNS GROVE TWP',
#     'PENNSAUKEN TWP',
#     'PENNSVILLE TWP',
#     'PEQUANNOCK TWP',
#     'PERTH AMBOY CITY',
#     'PHILLIPSBURG TOWN',
#     'PILESGROVE TWP',
#     'PINE BEACH BORO',
#     'PINE HILL BORO',
#     'PINE VALLEY BORO',
#     'PISCATAWAY TWP',
#     'PITMAN BORO',
#     'PITTSGROVE TWP',
#     'PLAINFIELD CITY',
#     'PLAINSBORO TWP',
#     'PLEASANTVILLE CITY',
#     'PLUMSTED TWP',
#     'POHATCONG TWP',
#     'POINT PLEASANT BEACH BORO',
#     'POINT PLEASANT BORO',
#     'POMPTON LAKES BORO',
#     'PORT REPUBLIC CITY',
#     'PRINCETON BORO',
#     'PRINCETON TWP',
#     'PROSPECT PARK BORO',
#     'QUINTON TWP',
#     'RAHWAY CITY',
#     'RAMSEY BORO',
#     'RANDOLPH TWP',
#     'RARITAN BORO',
#     'RARITAN TWP',
#     'READINGTON TWP',
#     'RED BANK BORO',
#     'RIDGEFIELD BORO',
#     'RIDGEFIELD PARK VILLAGE',
#     'RIDGEWOOD VILLAGE',
#     'RINGWOOD BORO',
#     'RIVERDALE BORO',
#     'RIVEREDGE BORO',
#     'RIVERSIDE TWP',
#     'RIVERTON BORO',
#     'RIVERVALE TWP',
#     'ROBBINSVILLE TWP',
#     'ROCHELLE PARK TWP',
#     'ROCKAWAY BORO',
#     'ROCKAWAY TWP',
#     'ROCKLEIGH BORO',
#     'ROCKY HILL BORO',
#     'ROOSEVELT BORO',
#     'ROSELAND BORO',
#     'ROSELLE BORO',
#     'ROSELLE PARK BORO',
#     'ROXBURY TWP',
#     'RUMSON BORO',
#     'RUNNEMEDE BORO',
#     'RUTHERFORD BORO',
#     'SADDLE BROOK TWP',
#     'SADDLE RIVER BORO',
#     'SALEM CITY',
#     'SANDYSTON BORO',
#     'SAYREVILLE BORO',
#     'SCOTCH PLAINS TWP',
#     'SEA BRIGHT BORO',
#     'SEA GIRT BORO',
#     'SEA ISLE CITY CITY',
#     'SEASIDE HEIGHTS BORO',
#     'SEASIDE PARK BORO',
#     'SECAUCUS TOWN',
#     'SHAMONG TWP',
#     'SHILOH BORO',
#     'SHIP BOTTOM BORO',
#     'SHREWSBURY BORO',
#     'SHREWSBURY TWP',
#     'SOMERDALE BORO',
#     'SOMERS POINT CITY',
#     'SOMERVILLE BORO',
#     'SOUTH AMBOY CITY',
#     'SOUTH BOUND BROOK BORO',
#     'SOUTH BRUNSWICK TWP',
#     'SOUTH HACKENSACK TWP',
#     'SOUTH HARRISON TWP',
#     'SOUTH ORANGE VILLAGE TWP',
#     'SOUTH PLAINSFIELD BORO',
#     'SOUTH RIVER BORO',
#     'SOUTH TOMS RIVER BORO',
#     'SOUTHAMPTON TWP',
#     'SPARTA TWP',
#     'SPOTSWOOD BORO',
#     'SPRING LAKE BORO',
#     'SPRING LAKE HEIGHTS BORO',
#     'SPRINGFIELD TWP',
#     'SPRINGFIELD TWP',
#     'STAFFORD BORO',
#     'STANHOPE BORO',
#     'STILLWATER TWP',
#     'STOCKTON BORO',
#     'STONE HARBOR BORO',
#     'STOW CREEK TWP',
#     'STRATFORD BORO',
#     'SUMMIT CITY',
#     'SURF CITY BORO',
#     'SUSSEX TWP',
#     'SWEDESBORO BORO',
#     'TABERNACLE TWP',
#     'TAVISTOCK BORO',
#     'TEANECK TWP',
#     'TENAFLY BORO',
#     'TETERBORO BORO',
#     'TEWKSBURY TWP',
#     'TINTON FALLS BORO',
#     'TOMS RIVER TOWNSHIP',
#     'TOTOWA BORO',
#     'TRENTON CITY',
#     'TUCKERTON BORO',
#     'UNION BEACH BORO',
#     'UNION CITY CITY',
#     'UNION TWP',
#     'UNION TWP',
#     'UPPER DEERFIELD TWP',
#     'UPPER FREEHOLD TWP',
#     'UPPER PITTSGROVE TWP',
#     'UPPER SADDLE RIVER BORO',
#     'UPPER TWP',
#     'VENTNOR CITY',
#     'VERNON TWP',
#     'VERONA BORO TWP',
#     'VICTORY GARDENS BORO',
#     'VINELAND CITY',
#     'VOORHEES TWP',
#     'WALDWICK BORO',
#     'WALL TWP',
#     'WALLINGTON BORO',
#     'WALPACK TWP',
#     'WANAQUE BORO',
#     'WANTAGE TWP',
#     'WARREN TWP',
#     'WASHINGTON BORO',
#     'WASHINGTON TWP',
#     'WASHINGTON TWP',
#     'WASHINGTON TWP',
#     'WASHINGTON TWP',
#     'WASHINGTON TWP',
#     'WATCHUNG BORO',
#     'WATERFORD TWP',
#     'WAYNE TWP',
#     'WEEHAWKEN TWP',
#     'WENONAH BORO',
#     'WEST AMWELL TWP',
#     'WEST CALDWELL TWP',
#     'WEST CAPE MAY BORO',
#     'WEST DEPTFORD TWP',
#     'WEST LONG BRANCH BORO',
#     'WEST MILFORD TWP',
#     'WEST NEW YORK TOWN',
#     'WEST ORANGE TWP',
#     'WEST PATERSON BORO',
#     'WEST WILDWOOD BORO',
#     'WEST WINDSOR TWP',
#     'WESTAMPTON TWP',
#     'WESTFIELD TOWN',
#     'WESTVILLE BORO',
#     'WESTWOOD BORO',
#     'WEYMOUTH TWP',
#     'WHARTON BORO',
#     'WHITE TWP',
#     'WILDWOOD CITY',
#     'WILDWOOD CREST BORO',
#     'WILLINGBORO TWP',
#     'WINFIELD TWP',
#     'WINSLOW TWP',
#     'WOOD-RIDGE BORO',
#     'WOODBINE BORO ',
#     'WOODBRIDGE TWP',
#     'WOODBURY CITY',
#     'WOODBURY HEIGHTS BORO',
#     'WOODCLIFF LAKE BORO',
#     'WOODLAND TWP',
#     'WOODLYNNE BORO',
#     'WOODSTOWN BORO',
#     'WOOLWICH TWP',
#     'WRIGHTSTOWN BORO',
#     'WYCKOFF TWP'
}

# %%
conv
# Out:
# {'ABERDEEN TWP': 'RemoveMe',
#  'ABSECON CITY': 'Absecon',
#  'ALEXANDRIA TWP': 'RemoveMe',
#  'ALLAMUCHY TWP': 'Allamuchy',
#  'ALLENDALE BORO': 'Allendale',
#  'ALLENHURST BORO': 'Allenhurst',
#  'ALLENTOWN BORO': 'Allentown',
#  'ALLOWAY TWP': 'Alloway',
#  'ALPHA BORO': 'RemoveMe',
#  'ALPINE BORO': 'Alpine',
#  'ANDOVER BORO': 'Andover',
#  'ANDOVER TWP': 'Andover',
#  'ASBURY PARK CITY': 'Asbury Park',
#  'ATLANTIC CITY CITY': 'Atlantic City',
#  'ATLANTIC HIGHLANDS BORO': 'Atlantic Highlands',
#  'AUDUBON BORO': 'Audubon',
#  'AUDUBON PARK BORO': 'RemoveMe',
#  'AVALON BORO': 'Augusta',
#  'AVON-BY-THE-SEA BOR': 'Avon By The Sea',
#  'BARNEGAT LIGHT BORO': 'Barnegat Light',
#  'BARNEGAT TWP': 'Barnegat',
#  'BARRINGTON BORO': 'Barrington'}

# %%
for index,row in sp2000.iterrows():
    print(conv[row['City']])
# Out:
# Absecon
# Atlantic City
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-83a7d099bddd> in <module>
#       1 for index,row in sp2000.iterrows():
# ----> 2     print(conv[row['City']])
#
# KeyError: 'BRIGANTINE CITY'

# %%
muni = requests.get("https://data.nj.gov/resource/k9xb-zgh4.json").json()

# %%
muni
# Out:
# [{'county_name_common': 'Atlantic County',
#   'municipality_name_common': 'Absecon',
#   'municipality_name_nj_1040': 'Absecon City',
#   'municipality_code_nj_1040': '0101',
#   'municipality_name_dca': 'Absecon City',
#   'municipality_code_dca': '0101',
#   'municipality_name_gnis': 'City of Absecon',
#   'municipality_code_gnis': '885134',
#   'municipality_code_fips': '3400100100'},
#  {'county_name_common': 'Atlantic County',
#   'municipality_name_common': 'Atlantic City',
#   'municipality_name_nj_1040': 'Atlantic City',
#   'municipality_code_nj_1040': '0102',
#   'municipality_name_dca': 'Atlantic City City',
#   'municipality_code_dca': '0102',
#   'municipality_name_gnis': 'City of Atlantic City',
#   'municipality_code_gnis': '885142',
#   'municipality_code_fips': '3400102080'},
#  {'county_name_common': 'Atlantic County',
#   'municipality_name_common': 'Brigantine',
#   'municipality_name_nj_1040': 'Brigantine City',
#   'municipality_code_nj_1040': '0103',
# ...

# %%
len(muni)
# Out:
# 565

# %%
pd.DataFrame(muni)
# Out:
#     county_name_common municipality_name_common municipality_name_nj_1040  \
# 0      Atlantic County                  Absecon              Absecon City
# 1      Atlantic County            Atlantic City             Atlantic City
# 2      Atlantic County               Brigantine           Brigantine City
# 3      Atlantic County            Buena Borough             Buena Borough
# 4      Atlantic County     Buena Vista Township      Buena Vista Township
# ..                 ...                      ...                       ...
# 560      Warren County             Phillipsburg         Phillipsburg Town
# 561      Warren County       Pohatcong Township        Pohatcong Township
# 562      Warren County       Washington Borough        Washington Borough
# 563      Warren County      Washington Township       Washington Township
# 564      Warren County           White Township            White Township
#
#     municipality_code_nj_1040 municipality_name_dca municipality_code_dca  \
# ...
